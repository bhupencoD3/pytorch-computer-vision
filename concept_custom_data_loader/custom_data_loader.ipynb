# %% [markdown]
# ###### 1.Data Gathering
# ###### 2.Data Preprocessing
# ###### 3.Feature Engineering
# ###### 4.Model Training
# ###### 5.Testing

# %% [markdown]
# ###### Dataset used: https://www.kaggle.com/datasets/mirichoi0218/insurance

# %%
import pandas as pd
# !conda install -c conda-forge pandas -y

# %%
df = pd.read_csv("../Linear Regression/insurance.csv")

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# !conda install -c conda-forge scikit-learn -y

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# ###### Split dataset before encoding

# %%
train_df,test_df = train_test_split(df,test_size=0.2,random_state=42)

# %% [markdown]
# ###### Encode categorical variable

# %%
label_encoder = {}
for col in ['sex','smoker','region']:
    le = LabelEncoder()
    train_df[col] = le.fit_transform(train_df[col])
    test_df[col] = le.transform(test_df[col])
    label_encoder[col] = le

# %% [markdown]
# ###### Features and Targets

# %%
X_train = train_df.drop(columns=['charges'])
y_train = train_df['charges']

X_test = test_df.drop(columns=['charges'])
y_test = test_df['charges']

# %%
X_train.head()
# Out:
#       age  sex    bmi  children  smoker  region
# 560    46    0  19.95         2       0       1
# 1285   47    0  24.32         0       0       0
# 1142   52    0  24.86         0       0       2
# 969    39    0  34.32         5       0       2
# 486    54    0  21.47         3       0       1

# %%
y_train.head()
# Out:
# 560      9193.83850
# 1285     8534.67180
# 1142    27117.99378
# 969      8596.82780
# 486     12475.35130
# Name: charges, dtype: float64

# %% [markdown]
# ###### Normalize Features

# %%
scaler = StandardScaler()


X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.47222651, -1.0246016 , -1.75652513,  0.73433626, -0.50874702,
#         -0.45611589],
#        [ 0.54331294, -1.0246016 , -1.03308239, -0.91119211, -0.50874702,
#         -1.35325561],
#        [ 0.8987451 , -1.0246016 , -0.94368672, -0.91119211, -0.50874702,
#          0.44102382],
#        ...,
#        [ 1.3252637 ,  0.97598911, -0.89153925, -0.91119211, -0.50874702,
#         -1.35325561],
#        [-0.16755139, -1.0246016 ,  2.82086429,  0.73433626,  1.96561348,
#          1.33816354],
#        [ 1.1120044 ,  0.97598911, -0.10932713, -0.91119211, -0.50874702,
#          1.33816354]])

# %% [markdown]
# ###### Convert to tensors

# %%
X_train_tensor = torch.tensor(X_train,dtype=torch.float32)
y_train_tensor = torch.tensor(y_train.values,dtype=torch.float32).view(-1,1)
X_test_tensor = torch.tensor(X_test,dtype=torch.float32)
y_test_tensor = torch.tensor(y_test.values,dtype=torch.float32).view(-1,1)

# %%
y_train_tensor.shape
# Out:
# torch.Size([1070, 1])

# %%
X_test.shape
# Out:
# (268, 6)

# %% [markdown]
# ###### Define Neural Network Model

# %%
class SimpleNNRegressionModel(nn.Module):
    def __init__(self,input_dim):
        super(SimpleNNRegressionModel,self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim,64),
            nn.ReLU(),
            nn.Linear(64,128),
            nn.ReLU(),
            nn.Linear(128,1)
        )    

    def forward(self,x):
        return self.network(x)

# %%
input_dim = X_train_tensor.shape[1]
model = SimpleNNRegressionModel(input_dim=input_dim)

# %%
model
# Out:
# SimpleNNRegressionModel(
#   (network): Sequential(
#     (0): Linear(in_features=6, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# ##### Loss and Optimizers

# %%
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(),lr=0.01)

# %% [markdown]
# ######
#
# ###### x_train_tensor = 1000000 ---> 10gb --> OOM(out of memory)
# ###### 1000000 ---> weights and bias calculation
#
# ###### we are teaching human: A book of 1000 pages --> student: 10 : student, i'm not able to understand.
# ###### 1000
# ###### 10 --> 100
# ###### 100 feedback = 1000 pages --> epoch
#
# ###### 1000 pages total
# ###### 100 epoch
# ###### 10 pages feedback
# ###### 100 iteration * 100
#
# ######

# %% [markdown]
# ##### Training Loop

# %%
# epochs = 30000

# for epoch in range(epochs):
#     model.train()
#     optimizer.zero_grad()
#     prediction = model(X_train_tensor)
#     loss = criterion(prediction,y_train_tensor)
#     loss.backward()


#     optimizer.step()

#     if (epoch+1) % 10 == 0:
#         print(f"Epoch [{epoch+1}/{epochs}],Loss:{loss.item():.4f}")

# %% [markdown]
# ##### Understanding Components of a Custom DataLoader in PyTorch

# %% [markdown]
# ###### 1. Dataset (torch.utils.data.Dataset)
# ###### 2. DataLoader (torch.utils.data.DataLoader)

# %% [markdown]
# #### Creating our own Custom Dataset in pytorch
# ###### init() --> initialised the dataset,loads data,applied preprocessing
# ###### len() -->  return the total number of samples in the dataset
# ###### getitem() --> Defines how to retrieve a single data sample when an index is provide

# %%
import torch
from torch.utils.data import Dataset,DataLoader

# %%
class InsuranceDataSet(Dataset):
    def __init__(self,X,y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        features = torch.tensor(self.X[idx],dtype=torch.float32)
        target = torch.tensor(self.y.values[idx],dtype=torch.float32)
        return features,target

# %%
dataset = InsuranceDataSet(X_train,y_train)

# %%
dataloader = DataLoader(dataset,batch_size=32,shuffle=True,num_workers=4)

# %%
for batch_idx,(features,targets) in enumerate(dataloader):
    print(f"Batch {batch_idx+1}:")
    print("Features:",features.shape)
    print("Targets",targets.shape)
    # if batch_idx == 5:
    #     break
# Out:
# Batch 1:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 2:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 3:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 4:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 5:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 6:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 7:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 8:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 9:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 10:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 11:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 12:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 13:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 14:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 15:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 16:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 17:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 18:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 19:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 20:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 21:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 22:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 23:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 24:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 25:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 26:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 27:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 28:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 29:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 30:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 31:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 32:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 33:
# Features: torch.Size([32, 6])
# Targets torch.Size([32])
# Batch 34:
# Features: torch.Size([14, 6])
# Targets torch.Size([14])

# %%
epochs = 1000

for epoch in range(epochs):
    model.train()

    for batch_idx,(batch_X, batch_y) in enumerate(dataloader):
        print(f"Current batch: {batch_idx}")
        optimizer.zero_grad()
        prediction = model(batch_X)
        loss = criterion(prediction,batch_y)
        loss.backward()


        optimizer.step()

        print(f"Batch [{batch_idx+1}/{epochs}],Loss:{loss.item():.4f}")

        if (epoch+1) % 100 == 0:
            print(f"Epoch [{epoch+1}/{epochs}],Loss:{loss.item():.4f}")
# Out:
# Current batch: 0
# Batch [1/1000],Loss:225601424.0000
# Current batch: 1
# Batch [2/1000],Loss:150816080.0000
# Current batch: 2
# Batch [3/1000],Loss:124603984.0000
# Current batch: 3
# Batch [4/1000],Loss:124175696.0000
# Current batch: 4
# Batch [5/1000],Loss:172308400.0000
# Current batch: 5
# Batch [6/1000],Loss:214159696.0000
# Current batch: 6
# Batch [7/1000],Loss:192323776.0000
# Current batch: 7
# Batch [8/1000],Loss:90564720.0000
# Current batch: 8
# Batch [9/1000],Loss:143669408.0000
# Current batch: 9
# Batch [10/1000],Loss:171751520.0000
# Current batch: 10
# Batch [11/1000],Loss:123288056.0000
# Current batch: 11
# Batch [12/1000],Loss:97344864.0000
# Current batch: 12
# Batch [13/1000],Loss:144550544.0000
# Current batch: 13
# Batch [14/1000],Loss:182598864.0000
# Current batch: 14
# Batch [15/1000],Loss:182096048.0000
# Current batch: 15
# Batch [16/1000],Loss:155770496.0000
# Current batch: 16
# Batch [17/1000],Loss:177026560.0000
# Current batch: 17
# Batch [18/1000],Loss:127618968.0000
# Current batch: 18
# Batch [19/1000],Loss:61929484.0000
# Current batch: 19
# Batch [20/1000],Loss:87024024.0000
# Current batch: 20
# Batch [21/1000],Loss:152603552.0000
# Current batch: 21
# Batch [22/1000],Loss:218829920.0000
# Current batch: 22
# Batch [23/1000],Loss:151004688.0000
# Current batch: 23
# Batch [24/1000],Loss:110227224.0000
# Current batch: 24
# Batch [25/1000],Loss:155185456.0000
# Current batch: 25
# Batch [26/1000],Loss:131034032.0000
# Current batch: 26
# Batch [27/1000],Loss:128416416.0000
# Current batch: 27
# Batch [28/1000],Loss:177968448.0000
# Current batch: 28
# Batch [29/1000],Loss:218890496.0000
# Current batch: 29
# Batch [30/1000],Loss:82206296.0000
# Current batch: 30
# Batch [31/1000],Loss:140050992.0000
# Current batch: 31
# Batch [32/1000],Loss:89788584.0000
# Current batch: 32
# Batch [33/1000],Loss:99114312.0000
# Current batch: 33
# Batch [34/1000],Loss:62251720.0000
# Current batch: 0
# Batch [1/1000],Loss:159750464.0000
# Current batch: 1
# Batch [2/1000],Loss:190000992.0000
# Current batch: 2
# Batch [3/1000],Loss:143496112.0000
# Current batch: 3
# Batch [4/1000],Loss:141046240.0000
# Current batch: 4
# Batch [5/1000],Loss:160081424.0000
# Current batch: 5
# Batch [6/1000],Loss:193815120.0000
# Current batch: 6
# Batch [7/1000],Loss:106495424.0000
# Current batch: 7
# Batch [8/1000],Loss:115523120.0000
# Current batch: 8
# Batch [9/1000],Loss:145088304.0000
# Current batch: 9
# Batch [10/1000],Loss:105089736.0000
# Current batch: 10
# Batch [11/1000],Loss:86091904.0000
# Current batch: 11
# Batch [12/1000],Loss:131323688.0000
# Current batch: 12
# Batch [13/1000],Loss:162067200.0000
# Current batch: 13
# Batch [14/1000],Loss:128503840.0000
# Current batch: 14
# Batch [15/1000],Loss:105522368.0000
# Current batch: 15
# Batch [16/1000],Loss:98875840.0000
# Current batch: 16
# Batch [17/1000],Loss:98631680.0000
# Current batch: 17
# Batch [18/1000],Loss:154983328.0000
# Current batch: 18
# Batch [19/1000],Loss:208729648.0000
# Current batch: 19
# Batch [20/1000],Loss:193690912.0000
# Current batch: 20
# Batch [21/1000],Loss:151515744.0000
# Current batch: 21
# Batch [22/1000],Loss:136420400.0000
# Current batch: 22
# Batch [23/1000],Loss:176632688.0000
# Current batch: 23
# Batch [24/1000],Loss:229748096.0000
# Current batch: 24
# Batch [25/1000],Loss:75956264.0000
# Current batch: 25
# Batch [26/1000],Loss:109484496.0000
# Current batch: 26
# Batch [27/1000],Loss:113272240.0000
# Current batch: 27
# Batch [28/1000],Loss:142855536.0000
# Current batch: 28
# Batch [29/1000],Loss:220996144.0000
# Current batch: 29
# Batch [30/1000],Loss:145671424.0000
# Current batch: 30
# Batch [31/1000],Loss:107223352.0000
# Current batch: 31
# Batch [32/1000],Loss:92100104.0000
# Current batch: 32
# Batch [33/1000],Loss:284848576.0000
# Current batch: 33
# Batch [34/1000],Loss:41626584.0000
# Current batch: 0
# Batch [1/1000],Loss:109107168.0000
# Current batch: 1
# Batch [2/1000],Loss:92667936.0000
# Current batch: 2
# Batch [3/1000],Loss:154956816.0000
# Current batch: 3
# Batch [4/1000],Loss:159636400.0000
# Current batch: 4
# Batch [5/1000],Loss:118388880.0000
# Current batch: 5
# Batch [6/1000],Loss:163800944.0000
# Current batch: 6
# Batch [7/1000],Loss:151038112.0000
# Current batch: 7
# Batch [8/1000],Loss:195186576.0000
# Current batch: 8
# Batch [9/1000],Loss:137309136.0000
# Current batch: 9
# Batch [10/1000],Loss:145807968.0000
# Current batch: 10
# Batch [11/1000],Loss:99925224.0000
# Current batch: 11
# Batch [12/1000],Loss:134723328.0000
# Current batch: 12
# Batch [13/1000],Loss:143968848.0000
# Current batch: 13
# Batch [14/1000],Loss:63632936.0000
# Current batch: 14
# Batch [15/1000],Loss:185172640.0000
# Current batch: 15
# Batch [16/1000],Loss:168424160.0000
# Current batch: 16
# Batch [17/1000],Loss:117572608.0000
# Current batch: 17
# Batch [18/1000],Loss:234445792.0000
# Current batch: 18
# Batch [19/1000],Loss:149208880.0000
# Current batch: 19
# Batch [20/1000],Loss:200256480.0000
# Current batch: 20
# Batch [21/1000],Loss:139202096.0000
# Current batch: 21
# Batch [22/1000],Loss:163722592.0000
# Current batch: 22
# Batch [23/1000],Loss:100681216.0000
# Current batch: 23
# Batch [24/1000],Loss:144980544.0000
# Current batch: 24
# Batch [25/1000],Loss:147867280.0000
# Current batch: 25
# Batch [26/1000],Loss:130482976.0000
# Current batch: 26
# Batch [27/1000],Loss:275561856.0000
# Current batch: 27
# Batch [28/1000],Loss:105597440.0000
# Current batch: 28
# Batch [29/1000],Loss:100443984.0000
# Current batch: 29
# Batch [30/1000],Loss:167869568.0000
# Current batch: 30
# Batch [31/1000],Loss:93086720.0000
# Current batch: 31
# Batch [32/1000],Loss:212365440.0000
# Current batch: 32
# Batch [33/1000],Loss:76181056.0000
# Current batch: 33
# Batch [34/1000],Loss:111049968.0000
# Current batch: 0
# Batch [1/1000],Loss:80125104.0000
# Current batch: 1
# Batch [2/1000],Loss:84986688.0000
# Current batch: 2
# Batch [3/1000],Loss:162584256.0000
# Current batch: 3
# Batch [4/1000],Loss:157431136.0000
# Current batch: 4
# Batch [5/1000],Loss:174929392.0000
# Current batch: 5
# Batch [6/1000],Loss:114013984.0000
# Current batch: 6
# Batch [7/1000],Loss:115754216.0000
# Current batch: 7
# Batch [8/1000],Loss:110172840.0000
# Current batch: 8
# Batch [9/1000],Loss:127692704.0000
# Current batch: 9
# Batch [10/1000],Loss:192779872.0000
# Current batch: 10
# Batch [11/1000],Loss:62092008.0000
# Current batch: 11
# Batch [12/1000],Loss:133845920.0000
# Current batch: 12
# Batch [13/1000],Loss:143240544.0000
# Current batch: 13
# Batch [14/1000],Loss:164275984.0000
# Current batch: 14
# Batch [15/1000],Loss:141820576.0000
# Current batch: 15
# Batch [16/1000],Loss:161989072.0000
# Current batch: 16
# Batch [17/1000],Loss:251371200.0000
# Current batch: 17
# Batch [18/1000],Loss:131177624.0000
# Current batch: 18
# Batch [19/1000],Loss:243897008.0000
# Current batch: 19
# Batch [20/1000],Loss:49553844.0000
# Current batch: 20
# Batch [21/1000],Loss:174191072.0000
# Current batch: 21
# Batch [22/1000],Loss:243908944.0000
# Current batch: 22
# Batch [23/1000],Loss:100071088.0000
# Current batch: 23
# Batch [24/1000],Loss:103860816.0000
# Current batch: 24
# Batch [25/1000],Loss:113956200.0000
# Current batch: 25
# Batch [26/1000],Loss:168524480.0000
# Current batch: 26
# Batch [27/1000],Loss:237079216.0000
# Current batch: 27
# Batch [28/1000],Loss:80911064.0000
# Current batch: 28
# Batch [29/1000],Loss:171372592.0000
# Current batch: 29
# Batch [30/1000],Loss:99739136.0000
# Current batch: 30
# Batch [31/1000],Loss:196017344.0000
# Current batch: 31
# Batch [32/1000],Loss:210445824.0000
# Current batch: 32
# Batch [33/1000],Loss:90020048.0000
# Current batch: 33
# Batch [34/1000],Loss:103979592.0000
# Current batch: 0
# Batch [1/1000],Loss:182083056.0000
# Current batch: 1
# Batch [2/1000],Loss:156507520.0000
# Current batch: 2
# Batch [3/1000],Loss:161275408.0000
# Current batch: 3
# Batch [4/1000],Loss:157317952.0000
# Current batch: 4
# Batch [5/1000],Loss:154255440.0000
# Current batch: 5
# Batch [6/1000],Loss:81606664.0000
# Current batch: 6
# Batch [7/1000],Loss:181050416.0000
# Current batch: 7
# Batch [8/1000],Loss:101474864.0000
# Current batch: 8
# Batch [9/1000],Loss:161400768.0000
# Current batch: 9
# Batch [10/1000],Loss:70076488.0000
# Current batch: 10
# Batch [11/1000],Loss:109066952.0000
# Current batch: 11
# Batch [12/1000],Loss:129236440.0000
# Current batch: 12
# Batch [13/1000],Loss:55933168.0000
# Current batch: 13
# Batch [14/1000],Loss:96816816.0000
# Current batch: 14
# Batch [15/1000],Loss:132735144.0000
# Current batch: 15
# Batch [16/1000],Loss:78969208.0000
# Current batch: 16
# Batch [17/1000],Loss:82542632.0000
# Current batch: 17
# Batch [18/1000],Loss:166578544.0000
# Current batch: 18
# Batch [19/1000],Loss:140898624.0000
# Current batch: 19
# Batch [20/1000],Loss:246926656.0000
# Current batch: 20
# Batch [21/1000],Loss:209474352.0000
# Current batch: 21
# Batch [22/1000],Loss:90101720.0000
# Current batch: 22
# Batch [23/1000],Loss:134424800.0000
# Current batch: 23
# Batch [24/1000],Loss:179889584.0000
# Current batch: 24
# Batch [25/1000],Loss:86487368.0000
# Current batch: 25
# Batch [26/1000],Loss:109788048.0000
# Current batch: 26
# Batch [27/1000],Loss:176696160.0000
# Current batch: 27
# Batch [28/1000],Loss:164493488.0000
# Current batch: 28
# Batch [29/1000],Loss:153055632.0000
# Current batch: 29
# Batch [30/1000],Loss:183287104.0000
# Current batch: 30
# Batch [31/1000],Loss:181693728.0000
# Current batch: 31
# Batch [32/1000],Loss:187986624.0000
# Current batch: 32
# Batch [33/1000],Loss:289420576.0000
# Current batch: 33
# Batch [34/1000],Loss:151130800.0000
# Current batch: 0
# Batch [1/1000],Loss:127736744.0000
# Current batch: 1
# Batch [2/1000],Loss:181730432.0000
# Current batch: 2
# Batch [3/1000],Loss:70151240.0000
# Current batch: 3
# Batch [4/1000],Loss:134306112.0000
# Current batch: 4
# Batch [5/1000],Loss:175224384.0000
# Current batch: 5
# Batch [6/1000],Loss:111206176.0000
# Current batch: 6
# Batch [7/1000],Loss:156784288.0000
# Current batch: 7
# Batch [8/1000],Loss:121603864.0000
# Current batch: 8
# Batch [9/1000],Loss:182922176.0000
# Current batch: 9
# Batch [10/1000],Loss:221586992.0000
# Current batch: 10
# Batch [11/1000],Loss:182149152.0000
# Current batch: 11
# Batch [12/1000],Loss:152134224.0000
# Current batch: 12
# Batch [13/1000],Loss:81737264.0000
# Current batch: 13
# Batch [14/1000],Loss:135325648.0000
# Current batch: 14
# Batch [15/1000],Loss:207460160.0000
# Current batch: 15
# Batch [16/1000],Loss:89774568.0000
# Current batch: 16
# Batch [17/1000],Loss:90010560.0000
# Current batch: 17
# Batch [18/1000],Loss:130513792.0000
# Current batch: 18
# Batch [19/1000],Loss:90836120.0000
# Current batch: 19
# Batch [20/1000],Loss:173365392.0000
# Current batch: 20
# Batch [21/1000],Loss:180676880.0000
# Current batch: 21
# Batch [22/1000],Loss:148407296.0000
# Current batch: 22
# Batch [23/1000],Loss:163714160.0000
# Current batch: 23
# Batch [24/1000],Loss:113172224.0000
# Current batch: 24
# Batch [25/1000],Loss:234518240.0000
# Current batch: 25
# Batch [26/1000],Loss:80080024.0000
# Current batch: 26
# Batch [27/1000],Loss:156846288.0000
# Current batch: 27
# Batch [28/1000],Loss:202207520.0000
# Current batch: 28
# Batch [29/1000],Loss:144106112.0000
# Current batch: 29
# Batch [30/1000],Loss:155819008.0000
# Current batch: 30
# Batch [31/1000],Loss:77379184.0000
# Current batch: 31
# Batch [32/1000],Loss:129226096.0000
# Current batch: 32
# Batch [33/1000],Loss:175453296.0000
# Current batch: 33
# Batch [34/1000],Loss:144739552.0000
# Current batch: 0
# Batch [1/1000],Loss:143854464.0000
# Current batch: 1
# Batch [2/1000],Loss:234171008.0000
# Current batch: 2
# Batch [3/1000],Loss:160520320.0000
# Current batch: 3
# Batch [4/1000],Loss:171493152.0000
# Current batch: 4
# Batch [5/1000],Loss:216568304.0000
# Current batch: 5
# Batch [6/1000],Loss:161266576.0000
# Current batch: 6
# Batch [7/1000],Loss:116230120.0000
# Current batch: 7
# Batch [8/1000],Loss:160898800.0000
# Current batch: 8
# Batch [9/1000],Loss:110872136.0000
# Current batch: 9
# Batch [10/1000],Loss:97404904.0000
# Current batch: 10
# Batch [11/1000],Loss:86550688.0000
# Current batch: 11
# Batch [12/1000],Loss:186944192.0000
# Current batch: 12
# Batch [13/1000],Loss:149294208.0000
# Current batch: 13
# Batch [14/1000],Loss:78973344.0000
# Current batch: 14
# Batch [15/1000],Loss:109145088.0000
# Current batch: 15
# Batch [16/1000],Loss:268261232.0000
# Current batch: 16
# Batch [17/1000],Loss:172298432.0000
# Current batch: 17
# Batch [18/1000],Loss:147057808.0000
# Current batch: 18
# Batch [19/1000],Loss:161936960.0000
# Current batch: 19
# Batch [20/1000],Loss:143749008.0000
# Current batch: 20
# Batch [21/1000],Loss:111256768.0000
# Current batch: 21
# Batch [22/1000],Loss:131335168.0000
# Current batch: 22
# Batch [23/1000],Loss:160588048.0000
# Current batch: 23
# Batch [24/1000],Loss:127998976.0000
# Current batch: 24
# Batch [25/1000],Loss:75010096.0000
# Current batch: 25
# Batch [26/1000],Loss:186046560.0000
# Current batch: 26
# Batch [27/1000],Loss:175158656.0000
# Current batch: 27
# Batch [28/1000],Loss:150380448.0000
# Current batch: 28
# Batch [29/1000],Loss:119946328.0000
# Current batch: 29
# Batch [30/1000],Loss:134356672.0000
# Current batch: 30
# Batch [31/1000],Loss:147868880.0000
# Current batch: 31
# Batch [32/1000],Loss:114957816.0000
# Current batch: 32
# Batch [33/1000],Loss:84667024.0000
# Current batch: 33
# Batch [34/1000],Loss:78397496.0000
# Current batch: 0
# Batch [1/1000],Loss:170669392.0000
# Current batch: 1
# Batch [2/1000],Loss:135586992.0000
# Current batch: 2
# Batch [3/1000],Loss:183090448.0000
# Current batch: 3
# Batch [4/1000],Loss:103525920.0000
# Current batch: 4
# Batch [5/1000],Loss:213904576.0000
# Current batch: 5
# Batch [6/1000],Loss:199873696.0000
# Current batch: 6
# Batch [7/1000],Loss:187302272.0000
# Current batch: 7
# Batch [8/1000],Loss:83313328.0000
# Current batch: 8
# Batch [9/1000],Loss:230853184.0000
# Current batch: 9
# Batch [10/1000],Loss:110463912.0000
# Current batch: 10
# Batch [11/1000],Loss:113032368.0000
# Current batch: 11
# Batch [12/1000],Loss:88164592.0000
# Current batch: 12
# Batch [13/1000],Loss:133908200.0000
# Current batch: 13
# Batch [14/1000],Loss:130753776.0000
# Current batch: 14
# Batch [15/1000],Loss:126844832.0000
# Current batch: 15
# Batch [16/1000],Loss:176499056.0000
# Current batch: 16
# Batch [17/1000],Loss:158535536.0000
# Current batch: 17
# Batch [18/1000],Loss:98498768.0000
# Current batch: 18
# Batch [19/1000],Loss:117820936.0000
# Current batch: 19
# Batch [20/1000],Loss:97982136.0000
# Current batch: 20
# Batch [21/1000],Loss:110445696.0000
# Current batch: 21
# Batch [22/1000],Loss:230465232.0000
# Current batch: 22
# Batch [23/1000],Loss:173858448.0000
# Current batch: 23
# Batch [24/1000],Loss:196908016.0000
# Current batch: 24
# Batch [25/1000],Loss:129318960.0000
# Current batch: 25
# Batch [26/1000],Loss:63214792.0000
# Current batch: 26
# Batch [27/1000],Loss:90571416.0000
# Current batch: 27
# Batch [28/1000],Loss:144979232.0000
# Current batch: 28
# Batch [29/1000],Loss:183696480.0000
# Current batch: 29
# Batch [30/1000],Loss:93879400.0000
# Current batch: 30
# Batch [31/1000],Loss:144670240.0000
# Current batch: 31
# Batch [32/1000],Loss:115333808.0000
# Current batch: 32
# Batch [33/1000],Loss:204964704.0000
# Current batch: 33
# Batch [34/1000],Loss:207763680.0000
# Current batch: 0
# Batch [1/1000],Loss:157955264.0000
# Current batch: 1
# Batch [2/1000],Loss:196265600.0000
# Current batch: 2
# Batch [3/1000],Loss:117944440.0000
# Current batch: 3
# Batch [4/1000],Loss:158799792.0000
# Current batch: 4
# Batch [5/1000],Loss:90890152.0000
# Current batch: 5
# Batch [6/1000],Loss:152785600.0000
# Current batch: 6
# Batch [7/1000],Loss:146088752.0000
# Current batch: 7
# Batch [8/1000],Loss:163771600.0000
# Current batch: 8
# Batch [9/1000],Loss:131191960.0000
# Current batch: 9
# Batch [10/1000],Loss:88507176.0000
# Current batch: 10
# Batch [11/1000],Loss:134513616.0000
# Current batch: 11
# Batch [12/1000],Loss:163109856.0000
# Current batch: 12
# Batch [13/1000],Loss:199092688.0000
# Current batch: 13
# Batch [14/1000],Loss:111279240.0000
# Current batch: 14
# Batch [15/1000],Loss:94194456.0000
# Current batch: 15
# Batch [16/1000],Loss:166151504.0000
# Current batch: 16
# Batch [17/1000],Loss:150522032.0000
# Current batch: 17
# Batch [18/1000],Loss:118039336.0000
# Current batch: 18
# Batch [19/1000],Loss:174243136.0000
# Current batch: 19
# Batch [20/1000],Loss:97724704.0000
# Current batch: 20
# Batch [21/1000],Loss:267714752.0000
# Current batch: 21
# Batch [22/1000],Loss:187551408.0000
# Current batch: 22
# Batch [23/1000],Loss:211018848.0000
# Current batch: 23
# Batch [24/1000],Loss:115774544.0000
# Current batch: 24
# Batch [25/1000],Loss:92203472.0000
# Current batch: 25
# Batch [26/1000],Loss:169013248.0000
# Current batch: 26
# Batch [27/1000],Loss:214226560.0000
# Current batch: 27
# Batch [28/1000],Loss:150118368.0000
# Current batch: 28
# Batch [29/1000],Loss:132863048.0000
# Current batch: 29
# Batch [30/1000],Loss:154111984.0000
# Current batch: 30
# Batch [31/1000],Loss:120158432.0000
# Current batch: 31
# Batch [32/1000],Loss:117444928.0000
# Current batch: 32
# Batch [33/1000],Loss:57467708.0000
# Current batch: 33
# Batch [34/1000],Loss:65802564.0000
# Current batch: 0
# Batch [1/1000],Loss:201203232.0000
# Current batch: 1
# Batch [2/1000],Loss:97465824.0000
# Current batch: 2
# Batch [3/1000],Loss:158185120.0000
# Current batch: 3
# Batch [4/1000],Loss:159636208.0000
# Current batch: 4
# Batch [5/1000],Loss:112652224.0000
# Current batch: 5
# Batch [6/1000],Loss:175888336.0000
# Current batch: 6
# Batch [7/1000],Loss:118231360.0000
# Current batch: 7
# Batch [8/1000],Loss:149087040.0000
# Current batch: 8
# Batch [9/1000],Loss:152120000.0000
# Current batch: 9
# Batch [10/1000],Loss:144086272.0000
# Current batch: 10
# Batch [11/1000],Loss:161165344.0000
# Current batch: 11
# Batch [12/1000],Loss:213898544.0000
# Current batch: 12
# Batch [13/1000],Loss:145422384.0000
# Current batch: 13
# Batch [14/1000],Loss:136245536.0000
# Current batch: 14
# Batch [15/1000],Loss:151961376.0000
# Current batch: 15
# Batch [16/1000],Loss:144359872.0000
# Current batch: 16
# Batch [17/1000],Loss:132606576.0000
# Current batch: 17
# Batch [18/1000],Loss:146160048.0000
# Current batch: 18
# Batch [19/1000],Loss:115456880.0000
# Current batch: 19
# Batch [20/1000],Loss:84608784.0000
# Current batch: 20
# Batch [21/1000],Loss:86403456.0000
# Current batch: 21
# Batch [22/1000],Loss:218503856.0000
# Current batch: 22
# Batch [23/1000],Loss:112650144.0000
# Current batch: 23
# Batch [24/1000],Loss:87100400.0000
# Current batch: 24
# Batch [25/1000],Loss:200757968.0000
# Current batch: 25
# Batch [26/1000],Loss:86332512.0000
# Current batch: 26
# Batch [27/1000],Loss:106883456.0000
# Current batch: 27
# Batch [28/1000],Loss:111871128.0000
# Current batch: 28
# Batch [29/1000],Loss:176814896.0000
# Current batch: 29
# Batch [30/1000],Loss:145163968.0000
# Current batch: 30
# Batch [31/1000],Loss:182651104.0000
# Current batch: 31
# Batch [32/1000],Loss:112376544.0000
# Current batch: 32
# Batch [33/1000],Loss:199372912.0000
# Current batch: 33
# Batch [34/1000],Loss:219617424.0000
# Current batch: 0
# Batch [1/1000],Loss:265417760.0000
# Current batch: 1
# Batch [2/1000],Loss:168234192.0000
# Current batch: 2
# Batch [3/1000],Loss:141552576.0000
# Current batch: 3
# Batch [4/1000],Loss:211996176.0000
# Current batch: 4
# Batch [5/1000],Loss:112497872.0000
# Current batch: 5
# Batch [6/1000],Loss:97917424.0000
# Current batch: 6
# Batch [7/1000],Loss:106436296.0000
# Current batch: 7
# Batch [8/1000],Loss:124569888.0000
# Current batch: 8
# Batch [9/1000],Loss:62561084.0000
# Current batch: 9
# Batch [10/1000],Loss:212121984.0000
# Current batch: 10
# Batch [11/1000],Loss:185034496.0000
# Current batch: 11
# Batch [12/1000],Loss:115932904.0000
# Current batch: 12
# Batch [13/1000],Loss:78547880.0000
# Current batch: 13
# Batch [14/1000],Loss:83057880.0000
# Current batch: 14
# Batch [15/1000],Loss:90592344.0000
# Current batch: 15
# Batch [16/1000],Loss:131478336.0000
# Current batch: 16
# Batch [17/1000],Loss:186392992.0000
# Current batch: 17
# Batch [18/1000],Loss:108513392.0000
# Current batch: 18
# Batch [19/1000],Loss:195568640.0000
# Current batch: 19
# Batch [20/1000],Loss:121214448.0000
# Current batch: 20
# Batch [21/1000],Loss:87006784.0000
# Current batch: 21
# Batch [22/1000],Loss:232870768.0000
# Current batch: 22
# Batch [23/1000],Loss:214060960.0000
# Current batch: 23
# Batch [24/1000],Loss:158905824.0000
# Current batch: 24
# Batch [25/1000],Loss:162921600.0000
# Current batch: 25
# Batch [26/1000],Loss:150178864.0000
# Current batch: 26
# Batch [27/1000],Loss:138340992.0000
# Current batch: 27
# Batch [28/1000],Loss:164631584.0000
# Current batch: 28
# Batch [29/1000],Loss:136121808.0000
# Current batch: 29
# Batch [30/1000],Loss:107240352.0000
# Current batch: 30
# Batch [31/1000],Loss:125061072.0000
# Current batch: 31
# Batch [32/1000],Loss:139462048.0000
# Current batch: 32
# Batch [33/1000],Loss:156283664.0000
# Current batch: 33
# Batch [34/1000],Loss:147396528.0000
# Current batch: 0
# Batch [1/1000],Loss:119387272.0000
# Current batch: 1
# Batch [2/1000],Loss:107434832.0000
# Current batch: 2
# Batch [3/1000],Loss:201270448.0000
# Current batch: 3
# Batch [4/1000],Loss:165709648.0000
# Current batch: 4
# Batch [5/1000],Loss:234935760.0000
# Current batch: 5
# Batch [6/1000],Loss:106203888.0000
# Current batch: 6
# Batch [7/1000],Loss:128190328.0000
# Current batch: 7
# Batch [8/1000],Loss:149864912.0000
# Current batch: 8
# Batch [9/1000],Loss:107453152.0000
# Current batch: 9
# Batch [10/1000],Loss:208188640.0000
# Current batch: 10
# Batch [11/1000],Loss:172270400.0000
# Current batch: 11
# Batch [12/1000],Loss:197633952.0000
# Current batch: 12
# Batch [13/1000],Loss:110162400.0000
# Current batch: 13
# Batch [14/1000],Loss:115533088.0000
# Current batch: 14
# Batch [15/1000],Loss:145408752.0000
# Current batch: 15
# Batch [16/1000],Loss:164459520.0000
# Current batch: 16
# Batch [17/1000],Loss:109893064.0000
# Current batch: 17
# Batch [18/1000],Loss:141360800.0000
# Current batch: 18
# Batch [19/1000],Loss:123650824.0000
# Current batch: 19
# Batch [20/1000],Loss:141230912.0000
# Current batch: 20
# Batch [21/1000],Loss:169057904.0000
# Current batch: 21
# Batch [22/1000],Loss:215850592.0000
# Current batch: 22
# Batch [23/1000],Loss:125041792.0000
# Current batch: 23
# Batch [24/1000],Loss:144355680.0000
# Current batch: 24
# Batch [25/1000],Loss:123890944.0000
# Current batch: 25
# Batch [26/1000],Loss:121856592.0000
# Current batch: 26
# Batch [27/1000],Loss:171354624.0000
# Current batch: 27
# Batch [28/1000],Loss:122451120.0000
# Current batch: 28
# Batch [29/1000],Loss:76665952.0000
# Current batch: 29
# Batch [30/1000],Loss:148235936.0000
# Current batch: 30
# Batch [31/1000],Loss:109135464.0000
# Current batch: 31
# Batch [32/1000],Loss:180758928.0000
# Current batch: 32
# Batch [33/1000],Loss:93167816.0000
# Current batch: 33
# Batch [34/1000],Loss:178814144.0000
# Current batch: 0
# Batch [1/1000],Loss:155853152.0000
# Current batch: 1
# Batch [2/1000],Loss:244170656.0000
# Current batch: 2
# Batch [3/1000],Loss:112160872.0000
# Current batch: 3
# Batch [4/1000],Loss:206458464.0000
# Current batch: 4
# Batch [5/1000],Loss:95874224.0000
# Current batch: 5
# Batch [6/1000],Loss:75508032.0000
# Current batch: 6
# Batch [7/1000],Loss:169116416.0000
# Current batch: 7
# Batch [8/1000],Loss:149024480.0000
# Current batch: 8
# Batch [9/1000],Loss:77031672.0000
# Current batch: 9
# Batch [10/1000],Loss:96478176.0000
# Current batch: 10
# Batch [11/1000],Loss:179968624.0000
# Current batch: 11
# Batch [12/1000],Loss:95969824.0000
# Current batch: 12
# Batch [13/1000],Loss:129075632.0000
# Current batch: 13
# Batch [14/1000],Loss:191915872.0000
# Current batch: 14
# Batch [15/1000],Loss:197290720.0000
# Current batch: 15
# Batch [16/1000],Loss:145576976.0000
# Current batch: 16
# Batch [17/1000],Loss:165823520.0000
# Current batch: 17
# Batch [18/1000],Loss:142748736.0000
# Current batch: 18
# Batch [19/1000],Loss:202151744.0000
# Current batch: 19
# Batch [20/1000],Loss:134615152.0000
# Current batch: 20
# Batch [21/1000],Loss:299878016.0000
# Current batch: 21
# Batch [22/1000],Loss:153626768.0000
# Current batch: 22
# Batch [23/1000],Loss:138877712.0000
# Current batch: 23
# Batch [24/1000],Loss:114368176.0000
# Current batch: 24
# Batch [25/1000],Loss:108627784.0000
# Current batch: 25
# Batch [26/1000],Loss:119214984.0000
# Current batch: 26
# Batch [27/1000],Loss:98761216.0000
# Current batch: 27
# Batch [28/1000],Loss:151164240.0000
# Current batch: 28
# Batch [29/1000],Loss:122099072.0000
# Current batch: 29
# Batch [30/1000],Loss:128207016.0000
# Current batch: 30
# Batch [31/1000],Loss:114035184.0000
# Current batch: 31
# Batch [32/1000],Loss:107737704.0000
# Current batch: 32
# Batch [33/1000],Loss:190723520.0000
# Current batch: 33
# Batch [34/1000],Loss:55049912.0000
# Current batch: 0
# Batch [1/1000],Loss:68614592.0000
# Current batch: 1
# Batch [2/1000],Loss:142201040.0000
# Current batch: 2
# Batch [3/1000],Loss:166034944.0000
# Current batch: 3
# Batch [4/1000],Loss:132270008.0000
# Current batch: 4
# Batch [5/1000],Loss:184224448.0000
# Current batch: 5
# Batch [6/1000],Loss:109957360.0000
# Current batch: 6
# Batch [7/1000],Loss:128121792.0000
# Current batch: 7
# Batch [8/1000],Loss:283605984.0000
# Current batch: 8
# Batch [9/1000],Loss:118866824.0000
# Current batch: 9
# Batch [10/1000],Loss:119248096.0000
# Current batch: 10
# Batch [11/1000],Loss:138203712.0000
# Current batch: 11
# Batch [12/1000],Loss:119400744.0000
# Current batch: 12
# Batch [13/1000],Loss:73458408.0000
# Current batch: 13
# Batch [14/1000],Loss:115515696.0000
# Current batch: 14
# Batch [15/1000],Loss:153993264.0000
# Current batch: 15
# Batch [16/1000],Loss:132952432.0000
# Current batch: 16
# Batch [17/1000],Loss:96460168.0000
# Current batch: 17
# Batch [18/1000],Loss:187426880.0000
# Current batch: 18
# Batch [19/1000],Loss:98340024.0000
# Current batch: 19
# Batch [20/1000],Loss:146339520.0000
# Current batch: 20
# Batch [21/1000],Loss:147314160.0000
# Current batch: 21
# Batch [22/1000],Loss:135536160.0000
# Current batch: 22
# Batch [23/1000],Loss:156715392.0000
# Current batch: 23
# Batch [24/1000],Loss:168858976.0000
# Current batch: 24
# Batch [25/1000],Loss:241182240.0000
# Current batch: 25
# Batch [26/1000],Loss:182457488.0000
# Current batch: 26
# Batch [27/1000],Loss:191236672.0000
# Current batch: 27
# Batch [28/1000],Loss:147850528.0000
# Current batch: 28
# Batch [29/1000],Loss:106398592.0000
# Current batch: 29
# Batch [30/1000],Loss:139565360.0000
# Current batch: 30
# Batch [31/1000],Loss:133899512.0000
# Current batch: 31
# Batch [32/1000],Loss:202873664.0000
# Current batch: 32
# Batch [33/1000],Loss:128953744.0000
# Current batch: 33
# Batch [34/1000],Loss:95373416.0000
# Current batch: 0
# Batch [1/1000],Loss:135753920.0000
# Current batch: 1
# Batch [2/1000],Loss:222130768.0000
# Current batch: 2
# Batch [3/1000],Loss:142819184.0000
# Current batch: 3
# Batch [4/1000],Loss:78855048.0000
# Current batch: 4
# Batch [5/1000],Loss:79680264.0000
# Current batch: 5
# Batch [6/1000],Loss:204611328.0000
# Current batch: 6
# Batch [7/1000],Loss:171239984.0000
# Current batch: 7
# Batch [8/1000],Loss:87872280.0000
# Current batch: 8
# Batch [9/1000],Loss:110140544.0000
# Current batch: 9
# Batch [10/1000],Loss:214636592.0000
# Current batch: 10
# Batch [11/1000],Loss:180758704.0000
# Current batch: 11
# Batch [12/1000],Loss:164367520.0000
# Current batch: 12
# Batch [13/1000],Loss:117522960.0000
# Current batch: 13
# Batch [14/1000],Loss:112149168.0000
# Current batch: 14
# Batch [15/1000],Loss:117774912.0000
# Current batch: 15
# Batch [16/1000],Loss:127714288.0000
# Current batch: 16
# Batch [17/1000],Loss:207131392.0000
# Current batch: 17
# Batch [18/1000],Loss:191180288.0000
# Current batch: 18
# Batch [19/1000],Loss:165339344.0000
# Current batch: 19
# Batch [20/1000],Loss:144559424.0000
# Current batch: 20
# Batch [21/1000],Loss:122944240.0000
# Current batch: 21
# Batch [22/1000],Loss:54349328.0000
# Current batch: 22
# Batch [23/1000],Loss:143932768.0000
# Current batch: 23
# Batch [24/1000],Loss:196500608.0000
# Current batch: 24
# Batch [25/1000],Loss:75010304.0000
# Current batch: 25
# Batch [26/1000],Loss:138615808.0000
# Current batch: 26
# Batch [27/1000],Loss:82317512.0000
# Current batch: 27
# Batch [28/1000],Loss:274304576.0000
# Current batch: 28
# Batch [29/1000],Loss:137930768.0000
# Current batch: 29
# Batch [30/1000],Loss:157950448.0000
# Current batch: 30
# Batch [31/1000],Loss:215708128.0000
# Current batch: 31
# Batch [32/1000],Loss:130518736.0000
# Current batch: 32
# Batch [33/1000],Loss:78910272.0000
# Current batch: 33
# Batch [34/1000],Loss:100631608.0000
# Current batch: 0
# Batch [1/1000],Loss:183240480.0000
# Current batch: 1
# Batch [2/1000],Loss:132014560.0000
# Current batch: 2
# Batch [3/1000],Loss:153861472.0000
# Current batch: 3
# Batch [4/1000],Loss:201334480.0000
# Current batch: 4
# Batch [5/1000],Loss:199480064.0000
# Current batch: 5
# Batch [6/1000],Loss:153978528.0000
# Current batch: 6
# Batch [7/1000],Loss:89478176.0000
# Current batch: 7
# Batch [8/1000],Loss:116603968.0000
# Current batch: 8
# Batch [9/1000],Loss:157111456.0000
# Current batch: 9
# Batch [10/1000],Loss:80320352.0000
# Current batch: 10
# Batch [11/1000],Loss:79285416.0000
# Current batch: 11
# Batch [12/1000],Loss:109212072.0000
# Current batch: 12
# Batch [13/1000],Loss:122442928.0000
# Current batch: 13
# Batch [14/1000],Loss:102035232.0000
# Current batch: 14
# Batch [15/1000],Loss:144375280.0000
# Current batch: 15
# Batch [16/1000],Loss:117822208.0000
# Current batch: 16
# Batch [17/1000],Loss:106193680.0000
# Current batch: 17
# Batch [18/1000],Loss:128059936.0000
# Current batch: 18
# Batch [19/1000],Loss:145509280.0000
# Current batch: 19
# Batch [20/1000],Loss:111925448.0000
# Current batch: 20
# Batch [21/1000],Loss:171303232.0000
# Current batch: 21
# Batch [22/1000],Loss:99727832.0000
# Current batch: 22
# Batch [23/1000],Loss:230652176.0000
# Current batch: 23
# Batch [24/1000],Loss:183580768.0000
# Current batch: 24
# Batch [25/1000],Loss:285820224.0000
# Current batch: 25
# Batch [26/1000],Loss:152589376.0000
# Current batch: 26
# Batch [27/1000],Loss:162035616.0000
# Current batch: 27
# Batch [28/1000],Loss:118447416.0000
# Current batch: 28
# Batch [29/1000],Loss:148916960.0000
# Current batch: 29
# Batch [30/1000],Loss:129083184.0000
# Current batch: 30
# Batch [31/1000],Loss:164151776.0000
# Current batch: 31
# Batch [32/1000],Loss:156112592.0000
# Current batch: 32
# Batch [33/1000],Loss:138679792.0000
# Current batch: 33
# Batch [34/1000],Loss:140238064.0000
# Current batch: 0
# Batch [1/1000],Loss:185979104.0000
# Current batch: 1
# Batch [2/1000],Loss:147386832.0000
# Current batch: 2
# Batch [3/1000],Loss:200845424.0000
# Current batch: 3
# Batch [4/1000],Loss:237576368.0000
# Current batch: 4
# Batch [5/1000],Loss:132181704.0000
# Current batch: 5
# Batch [6/1000],Loss:193595824.0000
# Current batch: 6
# Batch [7/1000],Loss:158290208.0000
# Current batch: 7
# Batch [8/1000],Loss:94735240.0000
# Current batch: 8
# Batch [9/1000],Loss:116100232.0000
# Current batch: 9
# Batch [10/1000],Loss:159298320.0000
# Current batch: 10
# Batch [11/1000],Loss:94319424.0000
# Current batch: 11
# Batch [12/1000],Loss:129061200.0000
# Current batch: 12
# Batch [13/1000],Loss:165869584.0000
# Current batch: 13
# Batch [14/1000],Loss:200436864.0000
# Current batch: 14
# Batch [15/1000],Loss:121221376.0000
# Current batch: 15
# Batch [16/1000],Loss:109168184.0000
# Current batch: 16
# Batch [17/1000],Loss:138639120.0000
# Current batch: 17
# Batch [18/1000],Loss:56138824.0000
# Current batch: 18
# Batch [19/1000],Loss:134935248.0000
# Current batch: 19
# Batch [20/1000],Loss:234801920.0000
# Current batch: 20
# Batch [21/1000],Loss:83794256.0000
# Current batch: 21
# Batch [22/1000],Loss:210738736.0000
# Current batch: 22
# Batch [23/1000],Loss:164795536.0000
# Current batch: 23
# Batch [24/1000],Loss:169343008.0000
# Current batch: 24
# Batch [25/1000],Loss:213913952.0000
# Current batch: 25
# Batch [26/1000],Loss:131917624.0000
# Current batch: 26
# Batch [27/1000],Loss:97104680.0000
# Current batch: 27
# Batch [28/1000],Loss:181327680.0000
# Current batch: 28
# Batch [29/1000],Loss:88517288.0000
# Current batch: 29
# Batch [30/1000],Loss:85702192.0000
# Current batch: 30
# Batch [31/1000],Loss:121265464.0000
# Current batch: 31
# Batch [32/1000],Loss:102781344.0000
# Current batch: 32
# Batch [33/1000],Loss:159109024.0000
# Current batch: 33
# Batch [34/1000],Loss:35260932.0000
# Current batch: 0
# Batch [1/1000],Loss:59485168.0000
# Current batch: 1
# Batch [2/1000],Loss:271822144.0000
# Current batch: 2
# Batch [3/1000],Loss:132796432.0000
# Current batch: 3
# Batch [4/1000],Loss:114629672.0000
# Current batch: 4
# Batch [5/1000],Loss:171128672.0000
# Current batch: 5
# Batch [6/1000],Loss:175101264.0000
# Current batch: 6
# Batch [7/1000],Loss:174892080.0000
# Current batch: 7
# Batch [8/1000],Loss:87337312.0000
# Current batch: 8
# Batch [9/1000],Loss:112106848.0000
# Current batch: 9
# Batch [10/1000],Loss:186384896.0000
# Current batch: 10
# Batch [11/1000],Loss:99369776.0000
# Current batch: 11
# Batch [12/1000],Loss:108176128.0000
# Current batch: 12
# Batch [13/1000],Loss:93176824.0000
# Current batch: 13
# Batch [14/1000],Loss:187801792.0000
# Current batch: 14
# Batch [15/1000],Loss:164109216.0000
# Current batch: 15
# Batch [16/1000],Loss:155321088.0000
# Current batch: 16
# Batch [17/1000],Loss:196789152.0000
# Current batch: 17
# Batch [18/1000],Loss:100166464.0000
# Current batch: 18
# Batch [19/1000],Loss:85085904.0000
# Current batch: 19
# Batch [20/1000],Loss:186009360.0000
# Current batch: 20
# Batch [21/1000],Loss:70818288.0000
# Current batch: 21
# Batch [22/1000],Loss:203880704.0000
# Current batch: 22
# Batch [23/1000],Loss:114552480.0000
# Current batch: 23
# Batch [24/1000],Loss:135009424.0000
# Current batch: 24
# Batch [25/1000],Loss:196055696.0000
# Current batch: 25
# Batch [26/1000],Loss:77438128.0000
# Current batch: 26
# Batch [27/1000],Loss:144314720.0000
# Current batch: 27
# Batch [28/1000],Loss:110022368.0000
# Current batch: 28
# Batch [29/1000],Loss:162647680.0000
# Current batch: 29
# Batch [30/1000],Loss:308876160.0000
# Current batch: 30
# Batch [31/1000],Loss:146588080.0000
# Current batch: 31
# Batch [32/1000],Loss:138729120.0000
# Current batch: 32
# Batch [33/1000],Loss:122153856.0000
# Current batch: 33
# Batch [34/1000],Loss:88685376.0000
# Current batch: 0
# Batch [1/1000],Loss:130710112.0000
# Current batch: 1
# Batch [2/1000],Loss:126910160.0000
# Current batch: 2
# Batch [3/1000],Loss:161416176.0000
# Current batch: 3
# Batch [4/1000],Loss:158938192.0000
# Current batch: 4
# Batch [5/1000],Loss:82124752.0000
# Current batch: 5
# Batch [6/1000],Loss:214305280.0000
# Current batch: 6
# Batch [7/1000],Loss:159743520.0000
# Current batch: 7
# Batch [8/1000],Loss:166848128.0000
# Current batch: 8
# Batch [9/1000],Loss:142489168.0000
# Current batch: 9
# Batch [10/1000],Loss:124776392.0000
# Current batch: 10
# Batch [11/1000],Loss:201929888.0000
# Current batch: 11
# Batch [12/1000],Loss:63217312.0000
# Current batch: 12
# Batch [13/1000],Loss:79902392.0000
# Current batch: 13
# Batch [14/1000],Loss:88556528.0000
# Current batch: 14
# Batch [15/1000],Loss:125528096.0000
# Current batch: 15
# Batch [16/1000],Loss:152532224.0000
# Current batch: 16
# Batch [17/1000],Loss:174445568.0000
# Current batch: 17
# Batch [18/1000],Loss:287188576.0000
# Current batch: 18
# Batch [19/1000],Loss:153862432.0000
# Current batch: 19
# Batch [20/1000],Loss:85458800.0000
# Current batch: 20
# Batch [21/1000],Loss:212035248.0000
# Current batch: 21
# Batch [22/1000],Loss:188367680.0000
# Current batch: 22
# Batch [23/1000],Loss:109611048.0000
# Current batch: 23
# Batch [24/1000],Loss:144257376.0000
# Current batch: 24
# Batch [25/1000],Loss:110418248.0000
# Current batch: 25
# Batch [26/1000],Loss:152843168.0000
# Current batch: 26
# Batch [27/1000],Loss:96774496.0000
# Current batch: 27
# Batch [28/1000],Loss:62162020.0000
# Current batch: 28
# Batch [29/1000],Loss:258282944.0000
# Current batch: 29
# Batch [30/1000],Loss:146050528.0000
# Current batch: 30
# Batch [31/1000],Loss:94220720.0000
# Current batch: 31
# Batch [32/1000],Loss:123627096.0000
# Current batch: 32
# Batch [33/1000],Loss:218697552.0000
# Current batch: 33
# Batch [34/1000],Loss:69369472.0000
# Current batch: 0
# Batch [1/1000],Loss:171658560.0000
# Current batch: 1
# Batch [2/1000],Loss:118224240.0000
# Current batch: 2
# Batch [3/1000],Loss:155151888.0000
# Current batch: 3
# Batch [4/1000],Loss:125690584.0000
# Current batch: 4
# Batch [5/1000],Loss:189281328.0000
# Current batch: 5
# Batch [6/1000],Loss:84417408.0000
# Current batch: 6
# Batch [7/1000],Loss:168756848.0000
# Current batch: 7
# Batch [8/1000],Loss:214403792.0000
# Current batch: 8
# Batch [9/1000],Loss:106745320.0000
# Current batch: 9
# Batch [10/1000],Loss:179732320.0000
# Current batch: 10
# Batch [11/1000],Loss:93712456.0000
# Current batch: 11
# Batch [12/1000],Loss:71646808.0000
# Current batch: 12
# Batch [13/1000],Loss:126542520.0000
# Current batch: 13
# Batch [14/1000],Loss:134920448.0000
# Current batch: 14
# Batch [15/1000],Loss:87885064.0000
# Current batch: 15
# Batch [16/1000],Loss:84372632.0000
# Current batch: 16
# Batch [17/1000],Loss:108417392.0000
# Current batch: 17
# Batch [18/1000],Loss:166040016.0000
# Current batch: 18
# Batch [19/1000],Loss:113857176.0000
# Current batch: 19
# Batch [20/1000],Loss:105414848.0000
# Current batch: 20
# Batch [21/1000],Loss:155856048.0000
# Current batch: 21
# Batch [22/1000],Loss:194646400.0000
# Current batch: 22
# Batch [23/1000],Loss:77745768.0000
# Current batch: 23
# Batch [24/1000],Loss:164883936.0000
# Current batch: 24
# Batch [25/1000],Loss:253394528.0000
# Current batch: 25
# Batch [26/1000],Loss:162881440.0000
# Current batch: 26
# Batch [27/1000],Loss:191692432.0000
# Current batch: 27
# Batch [28/1000],Loss:282070976.0000
# Current batch: 28
# Batch [29/1000],Loss:135735632.0000
# Current batch: 29
# Batch [30/1000],Loss:100104352.0000
# Current batch: 30
# Batch [31/1000],Loss:101595848.0000
# Current batch: 31
# Batch [32/1000],Loss:146267824.0000
# Current batch: 32
# Batch [33/1000],Loss:225617808.0000
# Current batch: 33
# Batch [34/1000],Loss:103074688.0000
# Current batch: 0
# Batch [1/1000],Loss:186072336.0000
# Current batch: 1
# Batch [2/1000],Loss:100645736.0000
# Current batch: 2
# Batch [3/1000],Loss:181247312.0000
# Current batch: 3
# Batch [4/1000],Loss:196374880.0000
# Current batch: 4
# Batch [5/1000],Loss:167233920.0000
# Current batch: 5
# Batch [6/1000],Loss:180744320.0000
# Current batch: 6
# Batch [7/1000],Loss:151021248.0000
# Current batch: 7
# Batch [8/1000],Loss:120082456.0000
# Current batch: 8
# Batch [9/1000],Loss:68863192.0000
# Current batch: 9
# Batch [10/1000],Loss:91605784.0000
# Current batch: 10
# Batch [11/1000],Loss:123604944.0000
# Current batch: 11
# Batch [12/1000],Loss:134047280.0000
# Current batch: 12
# Batch [13/1000],Loss:175510032.0000
# Current batch: 13
# Batch [14/1000],Loss:191551360.0000
# Current batch: 14
# Batch [15/1000],Loss:176438912.0000
# Current batch: 15
# Batch [16/1000],Loss:105686808.0000
# Current batch: 16
# Batch [17/1000],Loss:136451808.0000
# Current batch: 17
# Batch [18/1000],Loss:99644424.0000
# Current batch: 18
# Batch [19/1000],Loss:120272304.0000
# Current batch: 19
# Batch [20/1000],Loss:146425392.0000
# Current batch: 20
# Batch [21/1000],Loss:116835008.0000
# Current batch: 21
# Batch [22/1000],Loss:154362080.0000
# Current batch: 22
# Batch [23/1000],Loss:117072688.0000
# Current batch: 23
# Batch [24/1000],Loss:284247968.0000
# Current batch: 24
# Batch [25/1000],Loss:180329088.0000
# Current batch: 25
# Batch [26/1000],Loss:119204664.0000
# Current batch: 26
# Batch [27/1000],Loss:156221392.0000
# Current batch: 27
# Batch [28/1000],Loss:134498512.0000
# Current batch: 28
# Batch [29/1000],Loss:128275488.0000
# Current batch: 29
# Batch [30/1000],Loss:79476048.0000
# Current batch: 30
# Batch [31/1000],Loss:134035648.0000
# Current batch: 31
# Batch [32/1000],Loss:138261152.0000
# Current batch: 32
# Batch [33/1000],Loss:223162400.0000
# Current batch: 33
# Batch [34/1000],Loss:32187936.0000
# Current batch: 0
# Batch [1/1000],Loss:151515904.0000
# Current batch: 1
# Batch [2/1000],Loss:219005776.0000
# Current batch: 2
# Batch [3/1000],Loss:148127936.0000
# Current batch: 3
# Batch [4/1000],Loss:148160928.0000
# Current batch: 4
# Batch [5/1000],Loss:173231920.0000
# Current batch: 5
# Batch [6/1000],Loss:125495520.0000
# Current batch: 6
# Batch [7/1000],Loss:178821312.0000
# Current batch: 7
# Batch [8/1000],Loss:171569744.0000
# Current batch: 8
# Batch [9/1000],Loss:135952032.0000
# Current batch: 9
# Batch [10/1000],Loss:58049224.0000
# Current batch: 10
# Batch [11/1000],Loss:178251664.0000
# Current batch: 11
# Batch [12/1000],Loss:112128816.0000
# Current batch: 12
# Batch [13/1000],Loss:113678960.0000
# Current batch: 13
# Batch [14/1000],Loss:92570064.0000
# Current batch: 14
# Batch [15/1000],Loss:144920560.0000
# Current batch: 15
# Batch [16/1000],Loss:127224672.0000
# Current batch: 16
# Batch [17/1000],Loss:151223520.0000
# Current batch: 17
# Batch [18/1000],Loss:171602896.0000
# Current batch: 18
# Batch [19/1000],Loss:209815888.0000
# Current batch: 19
# Batch [20/1000],Loss:108923880.0000
# Current batch: 20
# Batch [21/1000],Loss:89618712.0000
# Current batch: 21
# Batch [22/1000],Loss:96894672.0000
# Current batch: 22
# Batch [23/1000],Loss:128700376.0000
# Current batch: 23
# Batch [24/1000],Loss:115048600.0000
# Current batch: 24
# Batch [25/1000],Loss:228127024.0000
# Current batch: 25
# Batch [26/1000],Loss:120284744.0000
# Current batch: 26
# Batch [27/1000],Loss:175388960.0000
# Current batch: 27
# Batch [28/1000],Loss:103738160.0000
# Current batch: 28
# Batch [29/1000],Loss:72901752.0000
# Current batch: 29
# Batch [30/1000],Loss:169334416.0000
# Current batch: 30
# Batch [31/1000],Loss:189507536.0000
# Current batch: 31
# Batch [32/1000],Loss:135578464.0000
# Current batch: 32
# Batch [33/1000],Loss:158578448.0000
# Current batch: 33
# Batch [34/1000],Loss:303082432.0000
# Current batch: 0
# Batch [1/1000],Loss:72905536.0000
# Current batch: 1
# Batch [2/1000],Loss:107105616.0000
# Current batch: 2
# Batch [3/1000],Loss:112316512.0000
# Current batch: 3
# Batch [4/1000],Loss:178119232.0000
# Current batch: 4
# Batch [5/1000],Loss:114184104.0000
# Current batch: 5
# Batch [6/1000],Loss:147375888.0000
# Current batch: 6
# Batch [7/1000],Loss:100979232.0000
# Current batch: 7
# Batch [8/1000],Loss:188881120.0000
# Current batch: 8
# Batch [9/1000],Loss:78671720.0000
# Current batch: 9
# Batch [10/1000],Loss:113727728.0000
# Current batch: 10
# Batch [11/1000],Loss:197102400.0000
# Current batch: 11
# Batch [12/1000],Loss:122680832.0000
# Current batch: 12
# Batch [13/1000],Loss:107034704.0000
# Current batch: 13
# Batch [14/1000],Loss:148177120.0000
# Current batch: 14
# Batch [15/1000],Loss:201410752.0000
# Current batch: 15
# Batch [16/1000],Loss:199587488.0000
# Current batch: 16
# Batch [17/1000],Loss:73711552.0000
# Current batch: 17
# Batch [18/1000],Loss:247661312.0000
# Current batch: 18
# Batch [19/1000],Loss:198780368.0000
# Current batch: 19
# Batch [20/1000],Loss:115286064.0000
# Current batch: 20
# Batch [21/1000],Loss:129401592.0000
# Current batch: 21
# Batch [22/1000],Loss:140467520.0000
# Current batch: 22
# Batch [23/1000],Loss:196861232.0000
# Current batch: 23
# Batch [24/1000],Loss:83578176.0000
# Current batch: 24
# Batch [25/1000],Loss:163974528.0000
# Current batch: 25
# Batch [26/1000],Loss:163273792.0000
# Current batch: 26
# Batch [27/1000],Loss:206851520.0000
# Current batch: 27
# Batch [28/1000],Loss:177725120.0000
# Current batch: 28
# Batch [29/1000],Loss:111409232.0000
# Current batch: 29
# Batch [30/1000],Loss:159338848.0000
# Current batch: 30
# Batch [31/1000],Loss:207903392.0000
# Current batch: 31
# Batch [32/1000],Loss:98638336.0000
# Current batch: 32
# Batch [33/1000],Loss:154390464.0000
# Current batch: 33
# Batch [34/1000],Loss:36836288.0000
# Current batch: 0
# Batch [1/1000],Loss:123627416.0000
# Current batch: 1
# Batch [2/1000],Loss:77677360.0000
# Current batch: 2
# Batch [3/1000],Loss:146597664.0000
# Current batch: 3
# Batch [4/1000],Loss:129248592.0000
# Current batch: 4
# Batch [5/1000],Loss:135040512.0000
# Current batch: 5
# Batch [6/1000],Loss:183699168.0000
# Current batch: 6
# Batch [7/1000],Loss:103290984.0000
# Current batch: 7
# Batch [8/1000],Loss:161888672.0000
# Current batch: 8
# Batch [9/1000],Loss:135151088.0000
# Current batch: 9
# Batch [10/1000],Loss:165221680.0000
# Current batch: 10
# Batch [11/1000],Loss:85108400.0000
# Current batch: 11
# Batch [12/1000],Loss:203327200.0000
# Current batch: 12
# Batch [13/1000],Loss:123146272.0000
# Current batch: 13
# Batch [14/1000],Loss:179513264.0000
# Current batch: 14
# Batch [15/1000],Loss:211241424.0000
# Current batch: 15
# Batch [16/1000],Loss:213754912.0000
# Current batch: 16
# Batch [17/1000],Loss:106004392.0000
# Current batch: 17
# Batch [18/1000],Loss:200978080.0000
# Current batch: 18
# Batch [19/1000],Loss:133912296.0000
# Current batch: 19
# Batch [20/1000],Loss:219276176.0000
# Current batch: 20
# Batch [21/1000],Loss:90024640.0000
# Current batch: 21
# Batch [22/1000],Loss:129621256.0000
# Current batch: 22
# Batch [23/1000],Loss:108813520.0000
# Current batch: 23
# Batch [24/1000],Loss:131142480.0000
# Current batch: 24
# Batch [25/1000],Loss:148626048.0000
# Current batch: 25
# Batch [26/1000],Loss:124852512.0000
# Current batch: 26
# Batch [27/1000],Loss:109865480.0000
# Current batch: 27
# Batch [28/1000],Loss:78244688.0000
# Current batch: 28
# Batch [29/1000],Loss:239507760.0000
# Current batch: 29
# Batch [30/1000],Loss:177385104.0000
# Current batch: 30
# Batch [31/1000],Loss:163123632.0000
# Current batch: 31
# Batch [32/1000],Loss:122460432.0000
# Current batch: 32
# Batch [33/1000],Loss:143322800.0000
# Current batch: 33
# Batch [34/1000],Loss:103083768.0000
# Current batch: 0
# Batch [1/1000],Loss:240019808.0000
# Current batch: 1
# Batch [2/1000],Loss:77798512.0000
# Current batch: 2
# Batch [3/1000],Loss:177462048.0000
# Current batch: 3
# Batch [4/1000],Loss:114355712.0000
# Current batch: 4
# Batch [5/1000],Loss:104248680.0000
# Current batch: 5
# Batch [6/1000],Loss:130964424.0000
# Current batch: 6
# Batch [7/1000],Loss:92210360.0000
# Current batch: 7
# Batch [8/1000],Loss:164015616.0000
# Current batch: 8
# Batch [9/1000],Loss:209575568.0000
# Current batch: 9
# Batch [10/1000],Loss:161877248.0000
# Current batch: 10
# Batch [11/1000],Loss:204947872.0000
# Current batch: 11
# Batch [12/1000],Loss:153555520.0000
# Current batch: 12
# Batch [13/1000],Loss:105255456.0000
# Current batch: 13
# Batch [14/1000],Loss:217291056.0000
# Current batch: 14
# Batch [15/1000],Loss:79407384.0000
# Current batch: 15
# Batch [16/1000],Loss:107254208.0000
# Current batch: 16
# Batch [17/1000],Loss:110930712.0000
# Current batch: 17
# Batch [18/1000],Loss:156200880.0000
# Current batch: 18
# Batch [19/1000],Loss:92332552.0000
# Current batch: 19
# Batch [20/1000],Loss:157504000.0000
# Current batch: 20
# Batch [21/1000],Loss:149831440.0000
# Current batch: 21
# Batch [22/1000],Loss:156068992.0000
# Current batch: 22
# Batch [23/1000],Loss:120500768.0000
# Current batch: 23
# Batch [24/1000],Loss:170291312.0000
# Current batch: 24
# Batch [25/1000],Loss:202826528.0000
# Current batch: 25
# Batch [26/1000],Loss:116703888.0000
# Current batch: 26
# Batch [27/1000],Loss:133577624.0000
# Current batch: 27
# Batch [28/1000],Loss:139624352.0000
# Current batch: 28
# Batch [29/1000],Loss:94275112.0000
# Current batch: 29
# Batch [30/1000],Loss:146870432.0000
# Current batch: 30
# Batch [31/1000],Loss:143104688.0000
# Current batch: 31
# Batch [32/1000],Loss:132366064.0000
# Current batch: 32
# Batch [33/1000],Loss:199803584.0000
# Current batch: 33
# Batch [34/1000],Loss:163279600.0000
# Current batch: 0
# Batch [1/1000],Loss:104690224.0000
# Current batch: 1
# Batch [2/1000],Loss:145862656.0000
# Current batch: 2
# Batch [3/1000],Loss:228842240.0000
# Current batch: 3
# Batch [4/1000],Loss:134267712.0000
# Current batch: 4
# Batch [5/1000],Loss:171609232.0000
# Current batch: 5
# Batch [6/1000],Loss:184791568.0000
# Current batch: 6
# Batch [7/1000],Loss:144874400.0000
# Current batch: 7
# Batch [8/1000],Loss:182326656.0000
# Current batch: 8
# Batch [9/1000],Loss:105052512.0000
# Current batch: 9
# Batch [10/1000],Loss:125686848.0000
# Current batch: 10
# Batch [11/1000],Loss:126983376.0000
# Current batch: 11
# Batch [12/1000],Loss:205175584.0000
# Current batch: 12
# Batch [13/1000],Loss:149211680.0000
# Current batch: 13
# Batch [14/1000],Loss:179190800.0000
# Current batch: 14
# Batch [15/1000],Loss:153455104.0000
# Current batch: 15
# Batch [16/1000],Loss:126342816.0000
# Current batch: 16
# Batch [17/1000],Loss:127200752.0000
# Current batch: 17
# Batch [18/1000],Loss:69327360.0000
# Current batch: 18
# Batch [19/1000],Loss:90652840.0000
# Current batch: 19
# Batch [20/1000],Loss:160074112.0000
# Current batch: 20
# Batch [21/1000],Loss:147490176.0000
# Current batch: 21
# Batch [22/1000],Loss:127584112.0000
# Current batch: 22
# Batch [23/1000],Loss:179035776.0000
# Current batch: 23
# Batch [24/1000],Loss:174895904.0000
# Current batch: 24
# Batch [25/1000],Loss:136270704.0000
# Current batch: 25
# Batch [26/1000],Loss:155584464.0000
# Current batch: 26
# Batch [27/1000],Loss:100765016.0000
# Current batch: 27
# Batch [28/1000],Loss:75253840.0000
# Current batch: 28
# Batch [29/1000],Loss:147083552.0000
# Current batch: 29
# Batch [30/1000],Loss:136804464.0000
# Current batch: 30
# Batch [31/1000],Loss:147748320.0000
# Current batch: 31
# Batch [32/1000],Loss:212840704.0000
# Current batch: 32
# Batch [33/1000],Loss:79711440.0000
# Current batch: 33
# Batch [34/1000],Loss:231114336.0000
# Current batch: 0
# Batch [1/1000],Loss:157184160.0000
# Current batch: 1
# Batch [2/1000],Loss:193746560.0000
# Current batch: 2
# Batch [3/1000],Loss:158058864.0000
# Current batch: 3
# Batch [4/1000],Loss:192592320.0000
# Current batch: 4
# Batch [5/1000],Loss:235463152.0000
# Current batch: 5
# Batch [6/1000],Loss:81203080.0000
# Current batch: 6
# Batch [7/1000],Loss:110050744.0000
# Current batch: 7
# Batch [8/1000],Loss:287327776.0000
# Current batch: 8
# Batch [9/1000],Loss:177061696.0000
# Current batch: 9
# Batch [10/1000],Loss:88277560.0000
# Current batch: 10
# Batch [11/1000],Loss:128618592.0000
# Current batch: 11
# Batch [12/1000],Loss:83089024.0000
# Current batch: 12
# Batch [13/1000],Loss:135890672.0000
# Current batch: 13
# Batch [14/1000],Loss:205072240.0000
# Current batch: 14
# Batch [15/1000],Loss:98501816.0000
# Current batch: 15
# Batch [16/1000],Loss:141397872.0000
# Current batch: 16
# Batch [17/1000],Loss:148766240.0000
# Current batch: 17
# ...
# Current batch: 30
# Batch [31/1000],Loss:204579264.0000
# Current batch: 31
# Batch [32/1000],Loss:84174168.0000
# Current batch: 32
# Batch [33/1000],Loss:165983136.0000
# Current batch: 33
# Batch [34/1000],Loss:110967336.0000
# Current batch: 0
# Batch [1/1000],Loss:86872720.0000
# Current batch: 1
# Batch [2/1000],Loss:248280256.0000
# Current batch: 2
# Batch [3/1000],Loss:240549408.0000
# Current batch: 3
# Batch [4/1000],Loss:157826000.0000
# Current batch: 4
# Batch [5/1000],Loss:94371296.0000
# Current batch: 5
# Batch [6/1000],Loss:131244992.0000
# Current batch: 6
# Batch [7/1000],Loss:219968544.0000
# Current batch: 7
# Batch [8/1000],Loss:137899888.0000
# Current batch: 8
# Batch [9/1000],Loss:172364784.0000
# Current batch: 9
# Batch [10/1000],Loss:105801104.0000
# Current batch: 10
# Batch [11/1000],Loss:197895920.0000
# Current batch: 11
# Batch [12/1000],Loss:122823376.0000
# Current batch: 12
# Batch [13/1000],Loss:82253648.0000
# Current batch: 13
# Batch [14/1000],Loss:113979616.0000
# Current batch: 14
# Batch [15/1000],Loss:227464352.0000
# Current batch: 15
# Batch [16/1000],Loss:176772416.0000
# Current batch: 16
# Batch [17/1000],Loss:80154976.0000
# Current batch: 17
# Batch [18/1000],Loss:173901424.0000
# Current batch: 18
# Batch [19/1000],Loss:107902960.0000
# Current batch: 19
# Batch [20/1000],Loss:195079248.0000
# Current batch: 20
# Batch [21/1000],Loss:162318944.0000
# Current batch: 21
# Batch [22/1000],Loss:142838256.0000
# Current batch: 22
# Batch [23/1000],Loss:96532216.0000
# Current batch: 23
# Batch [24/1000],Loss:162905696.0000
# Current batch: 24
# Batch [25/1000],Loss:128609520.0000
# Current batch: 25
# Batch [26/1000],Loss:194189824.0000
# Current batch: 26
# Batch [27/1000],Loss:106049496.0000
# Current batch: 27
# Batch [28/1000],Loss:119675960.0000
# Current batch: 28
# Batch [29/1000],Loss:149261024.0000
# Current batch: 29
# Batch [30/1000],Loss:157531536.0000
# Current batch: 30
# Batch [31/1000],Loss:118473168.0000
# Current batch: 31
# Batch [32/1000],Loss:85055920.0000
# Current batch: 32
# Batch [33/1000],Loss:69617528.0000
# Current batch: 33
# Batch [34/1000],Loss:142728672.0000
# Current batch: 0
# Batch [1/1000],Loss:57254768.0000
# Current batch: 1
# Batch [2/1000],Loss:119472088.0000
# Current batch: 2
# Batch [3/1000],Loss:189047664.0000
# Current batch: 3
# Batch [4/1000],Loss:80601104.0000
# Current batch: 4
# Batch [5/1000],Loss:140183760.0000
# Current batch: 5
# Batch [6/1000],Loss:171933120.0000
# Current batch: 6
# Batch [7/1000],Loss:181787472.0000
# Current batch: 7
# Batch [8/1000],Loss:128735424.0000
# Current batch: 8
# Batch [9/1000],Loss:122001304.0000
# Current batch: 9
# Batch [10/1000],Loss:304727712.0000
# Current batch: 10
# Batch [11/1000],Loss:228646848.0000
# Current batch: 11
# Batch [12/1000],Loss:109830432.0000
# Current batch: 12
# Batch [13/1000],Loss:94940832.0000
# Current batch: 13
# Batch [14/1000],Loss:221109600.0000
# Current batch: 14
# Batch [15/1000],Loss:147144960.0000
# Current batch: 15
# Batch [16/1000],Loss:234856080.0000
# Current batch: 16
# Batch [17/1000],Loss:88112744.0000
# Current batch: 17
# Batch [18/1000],Loss:163134624.0000
# Current batch: 18
# Batch [19/1000],Loss:91854512.0000
# Current batch: 19
# Batch [20/1000],Loss:144724624.0000
# Current batch: 20
# Batch [21/1000],Loss:148816480.0000
# Current batch: 21
# Batch [22/1000],Loss:120743368.0000
# Current batch: 22
# Batch [23/1000],Loss:174767392.0000
# Current batch: 23
# Batch [24/1000],Loss:70537424.0000
# Current batch: 24
# Batch [25/1000],Loss:199538112.0000
# Current batch: 25
# Batch [26/1000],Loss:125056792.0000
# Current batch: 26
# Batch [27/1000],Loss:134979184.0000
# Current batch: 27
# Batch [28/1000],Loss:141681024.0000
# Current batch: 28
# Batch [29/1000],Loss:119098352.0000
# Current batch: 29
# Batch [30/1000],Loss:125182952.0000
# Current batch: 30
# Batch [31/1000],Loss:102644320.0000
# Current batch: 31
# Batch [32/1000],Loss:128807472.0000
# Current batch: 32
# Batch [33/1000],Loss:188472928.0000
# Current batch: 33
# Batch [34/1000],Loss:71890512.0000
# Current batch: 0
# Batch [1/1000],Loss:108649824.0000
# Current batch: 1
# Batch [2/1000],Loss:180202240.0000
# Current batch: 2
# Batch [3/1000],Loss:130045400.0000
# Current batch: 3
# Batch [4/1000],Loss:244928096.0000
# Current batch: 4
# Batch [5/1000],Loss:191277776.0000
# Current batch: 5
# Batch [6/1000],Loss:88150392.0000
# Current batch: 6
# Batch [7/1000],Loss:152970304.0000
# Current batch: 7
# Batch [8/1000],Loss:215131488.0000
# Current batch: 8
# Batch [9/1000],Loss:125074728.0000
# Current batch: 9
# Batch [10/1000],Loss:145160000.0000
# Current batch: 10
# Batch [11/1000],Loss:232750224.0000
# Current batch: 11
# Batch [12/1000],Loss:177745424.0000
# Current batch: 12
# Batch [13/1000],Loss:169596768.0000
# Current batch: 13
# Batch [14/1000],Loss:157986672.0000
# Current batch: 14
# Batch [15/1000],Loss:170062976.0000
# Current batch: 15
# Batch [16/1000],Loss:153734656.0000
# Current batch: 16
# Batch [17/1000],Loss:132676624.0000
# Current batch: 17
# Batch [18/1000],Loss:106813128.0000
# Current batch: 18
# Batch [19/1000],Loss:199564672.0000
# Current batch: 19
# Batch [20/1000],Loss:181132624.0000
# Current batch: 20
# Batch [21/1000],Loss:134635088.0000
# Current batch: 21
# Batch [22/1000],Loss:116243264.0000
# Current batch: 22
# Batch [23/1000],Loss:173397760.0000
# Current batch: 23
# Batch [24/1000],Loss:113146776.0000
# Current batch: 24
# Batch [25/1000],Loss:114240424.0000
# Current batch: 25
# Batch [26/1000],Loss:56862352.0000
# Current batch: 26
# Batch [27/1000],Loss:128138576.0000
# Current batch: 27
# Batch [28/1000],Loss:110734192.0000
# Current batch: 28
# Batch [29/1000],Loss:85470072.0000
# Current batch: 29
# Batch [30/1000],Loss:136291168.0000
# Current batch: 30
# Batch [31/1000],Loss:168722736.0000
# Current batch: 31
# Batch [32/1000],Loss:116736272.0000
# Current batch: 32
# Batch [33/1000],Loss:71699816.0000
# Current batch: 33
# Batch [34/1000],Loss:127152736.0000
# Current batch: 0
# Batch [1/1000],Loss:132297144.0000
# Current batch: 1
# Batch [2/1000],Loss:109741880.0000
# Current batch: 2
# Batch [3/1000],Loss:212281152.0000
# Current batch: 3
# Batch [4/1000],Loss:138258608.0000
# Current batch: 4
# Batch [5/1000],Loss:164747744.0000
# Current batch: 5
# Batch [6/1000],Loss:125645728.0000
# Current batch: 6
# Batch [7/1000],Loss:75378736.0000
# Current batch: 7
# Batch [8/1000],Loss:78018896.0000
# Current batch: 8
# Batch [9/1000],Loss:146085472.0000
# Current batch: 9
# Batch [10/1000],Loss:246108688.0000
# Current batch: 10
# Batch [11/1000],Loss:182231040.0000
# Current batch: 11
# Batch [12/1000],Loss:59572848.0000
# Current batch: 12
# Batch [13/1000],Loss:148749184.0000
# Current batch: 13
# Batch [14/1000],Loss:106948112.0000
# Current batch: 14
# Batch [15/1000],Loss:127605432.0000
# Current batch: 15
# Batch [16/1000],Loss:184076656.0000
# Current batch: 16
# Batch [17/1000],Loss:93372608.0000
# Current batch: 17
# Batch [18/1000],Loss:118772824.0000
# Current batch: 18
# Batch [19/1000],Loss:92348912.0000
# Current batch: 19
# Batch [20/1000],Loss:171246560.0000
# Current batch: 20
# Batch [21/1000],Loss:142822848.0000
# Current batch: 21
# Batch [22/1000],Loss:164062112.0000
# Current batch: 22
# Batch [23/1000],Loss:124177104.0000
# Current batch: 23
# Batch [24/1000],Loss:162152368.0000
# Current batch: 24
# Batch [25/1000],Loss:199042128.0000
# Current batch: 25
# Batch [26/1000],Loss:72126352.0000
# Current batch: 26
# Batch [27/1000],Loss:292177568.0000
# Current batch: 27
# Batch [28/1000],Loss:114722912.0000
# Current batch: 28
# Batch [29/1000],Loss:129345144.0000
# Current batch: 29
# Batch [30/1000],Loss:215073664.0000
# Current batch: 30
# Batch [31/1000],Loss:120577056.0000
# Current batch: 31
# Batch [32/1000],Loss:122204344.0000
# Current batch: 32
# Batch [33/1000],Loss:207335680.0000
# Current batch: 33
# Batch [34/1000],Loss:135929520.0000
# Current batch: 0
# Batch [1/1000],Loss:240315520.0000
# Current batch: 1
# Batch [2/1000],Loss:186079040.0000
# Current batch: 2
# Batch [3/1000],Loss:166833792.0000
# Current batch: 3
# Batch [4/1000],Loss:165003968.0000
# Current batch: 4
# Batch [5/1000],Loss:134199248.0000
# Current batch: 5
# Batch [6/1000],Loss:146899280.0000
# Current batch: 6
# Batch [7/1000],Loss:79346640.0000
# Current batch: 7
# Batch [8/1000],Loss:111695752.0000
# Current batch: 8
# Batch [9/1000],Loss:142496800.0000
# Current batch: 9
# Batch [10/1000],Loss:106617328.0000
# Current batch: 10
# Batch [11/1000],Loss:149035968.0000
# Current batch: 11
# Batch [12/1000],Loss:131136640.0000
# Current batch: 12
# Batch [13/1000],Loss:96820176.0000
# Current batch: 13
# Batch [14/1000],Loss:142143344.0000
# Current batch: 14
# Batch [15/1000],Loss:112083176.0000
# Current batch: 15
# Batch [16/1000],Loss:135127680.0000
# Current batch: 16
# Batch [17/1000],Loss:61993224.0000
# Current batch: 17
# Batch [18/1000],Loss:165926080.0000
# Current batch: 18
# Batch [19/1000],Loss:90840552.0000
# Current batch: 19
# Batch [20/1000],Loss:137348304.0000
# Current batch: 20
# Batch [21/1000],Loss:249093632.0000
# Current batch: 21
# Batch [22/1000],Loss:188735456.0000
# Current batch: 22
# Batch [23/1000],Loss:201302528.0000
# Current batch: 23
# Batch [24/1000],Loss:150530368.0000
# Current batch: 24
# Batch [25/1000],Loss:222040000.0000
# Current batch: 25
# Batch [26/1000],Loss:120717208.0000
# Current batch: 26
# Batch [27/1000],Loss:196907904.0000
# Current batch: 27
# Batch [28/1000],Loss:77083472.0000
# Current batch: 28
# Batch [29/1000],Loss:98769528.0000
# Current batch: 29
# Batch [30/1000],Loss:186510080.0000
# Current batch: 30
# Batch [31/1000],Loss:105849056.0000
# Current batch: 31
# Batch [32/1000],Loss:177213968.0000
# Current batch: 32
# Batch [33/1000],Loss:113206560.0000
# Current batch: 33
# Batch [34/1000],Loss:134416528.0000
# Current batch: 0
# Batch [1/1000],Loss:133068976.0000
# Current batch: 1
# Batch [2/1000],Loss:142331584.0000
# Current batch: 2
# Batch [3/1000],Loss:125876864.0000
# Current batch: 3
# Batch [4/1000],Loss:65079508.0000
# Current batch: 4
# Batch [5/1000],Loss:162789440.0000
# Current batch: 5
# Batch [6/1000],Loss:163270672.0000
# Current batch: 6
# Batch [7/1000],Loss:140377216.0000
# Current batch: 7
# Batch [8/1000],Loss:84167712.0000
# Current batch: 8
# Batch [9/1000],Loss:121931216.0000
# Current batch: 9
# Batch [10/1000],Loss:96337592.0000
# Current batch: 10
# Batch [11/1000],Loss:111385408.0000
# Current batch: 11
# Batch [12/1000],Loss:199827856.0000
# Current batch: 12
# Batch [13/1000],Loss:102631240.0000
# Current batch: 13
# Batch [14/1000],Loss:115518944.0000
# Current batch: 14
# Batch [15/1000],Loss:111739256.0000
# Current batch: 15
# Batch [16/1000],Loss:185199536.0000
# Current batch: 16
# Batch [17/1000],Loss:192380128.0000
# Current batch: 17
# Batch [18/1000],Loss:119186688.0000
# Current batch: 18
# Batch [19/1000],Loss:205065456.0000
# Current batch: 19
# Batch [20/1000],Loss:126386672.0000
# Current batch: 20
# Batch [21/1000],Loss:197266336.0000
# Current batch: 21
# Batch [22/1000],Loss:178564112.0000
# Current batch: 22
# Batch [23/1000],Loss:242864560.0000
# Current batch: 23
# Batch [24/1000],Loss:145654736.0000
# Current batch: 24
# Batch [25/1000],Loss:285915168.0000
# Current batch: 25
# Batch [26/1000],Loss:140898560.0000
# Current batch: 26
# Batch [27/1000],Loss:125971704.0000
# Current batch: 27
# Batch [28/1000],Loss:121930392.0000
# Current batch: 28
# Batch [29/1000],Loss:130918808.0000
# Current batch: 29
# Batch [30/1000],Loss:165768480.0000
# Current batch: 30
# Batch [31/1000],Loss:119604744.0000
# Current batch: 31
# Batch [32/1000],Loss:114557528.0000
# Current batch: 32
# Batch [33/1000],Loss:79230208.0000
# Current batch: 33
# Batch [34/1000],Loss:198828512.0000
# Current batch: 0
# Batch [1/1000],Loss:60249004.0000
# Current batch: 1
# Batch [2/1000],Loss:83838696.0000
# Current batch: 2
# Batch [3/1000],Loss:154833184.0000
# Current batch: 3
# Batch [4/1000],Loss:94824760.0000
# Current batch: 4
# Batch [5/1000],Loss:201454688.0000
# Current batch: 5
# Batch [6/1000],Loss:134666720.0000
# Current batch: 6
# Batch [7/1000],Loss:158135808.0000
# Current batch: 7
# Batch [8/1000],Loss:159266144.0000
# Current batch: 8
# Batch [9/1000],Loss:208540576.0000
# Current batch: 9
# Batch [10/1000],Loss:85342840.0000
# Current batch: 10
# Batch [11/1000],Loss:72841224.0000
# Current batch: 11
# Batch [12/1000],Loss:63636184.0000
# Current batch: 12
# Batch [13/1000],Loss:148195424.0000
# Current batch: 13
# Batch [14/1000],Loss:114131056.0000
# Current batch: 14
# Batch [15/1000],Loss:193200400.0000
# Current batch: 15
# Batch [16/1000],Loss:153823792.0000
# Current batch: 16
# Batch [17/1000],Loss:210983408.0000
# Current batch: 17
# Batch [18/1000],Loss:75815192.0000
# Current batch: 18
# Batch [19/1000],Loss:165410832.0000
# Current batch: 19
# Batch [20/1000],Loss:109260808.0000
# Current batch: 20
# Batch [21/1000],Loss:69920656.0000
# Current batch: 21
# Batch [22/1000],Loss:161788960.0000
# Current batch: 22
# Batch [23/1000],Loss:168919056.0000
# Current batch: 23
# Batch [24/1000],Loss:163296608.0000
# Current batch: 24
# Batch [25/1000],Loss:90917264.0000
# Current batch: 25
# Batch [26/1000],Loss:130603808.0000
# Current batch: 26
# Batch [27/1000],Loss:225815376.0000
# Current batch: 27
# Batch [28/1000],Loss:219083376.0000
# Current batch: 28
# Batch [29/1000],Loss:128903888.0000
# Current batch: 29
# Batch [30/1000],Loss:164749312.0000
# Current batch: 30
# Batch [31/1000],Loss:162013104.0000
# Current batch: 31
# Batch [32/1000],Loss:224079872.0000
# Current batch: 32
# Batch [33/1000],Loss:157934176.0000
# Current batch: 33
# Batch [34/1000],Loss:279695232.0000
# Current batch: 0
# Batch [1/1000],Loss:243195536.0000
# Epoch [1000/1000],Loss:243195536.0000
# Current batch: 1
# Batch [2/1000],Loss:123641280.0000
# Epoch [1000/1000],Loss:123641280.0000
# Current batch: 2
# Batch [3/1000],Loss:106355424.0000
# Epoch [1000/1000],Loss:106355424.0000
# Current batch: 3
# Batch [4/1000],Loss:108685024.0000
# Epoch [1000/1000],Loss:108685024.0000
# Current batch: 4
# Batch [5/1000],Loss:140348320.0000
# Epoch [1000/1000],Loss:140348320.0000
# Current batch: 5
# Batch [6/1000],Loss:190760704.0000
# Epoch [1000/1000],Loss:190760704.0000
# Current batch: 6
# Batch [7/1000],Loss:148682464.0000
# Epoch [1000/1000],Loss:148682464.0000
# Current batch: 7
# Batch [8/1000],Loss:121175536.0000
# Epoch [1000/1000],Loss:121175536.0000
# Current batch: 8
# Batch [9/1000],Loss:167769520.0000
# Epoch [1000/1000],Loss:167769520.0000
# Current batch: 9
# Batch [10/1000],Loss:104696232.0000
# Epoch [1000/1000],Loss:104696232.0000
# Current batch: 10
# Batch [11/1000],Loss:137941392.0000
# Epoch [1000/1000],Loss:137941392.0000
# Current batch: 11
# Batch [12/1000],Loss:158075616.0000
# Epoch [1000/1000],Loss:158075616.0000
# Current batch: 12
# Batch [13/1000],Loss:155998368.0000
# Epoch [1000/1000],Loss:155998368.0000
# Current batch: 13
# Batch [14/1000],Loss:111808392.0000
# Epoch [1000/1000],Loss:111808392.0000
# Current batch: 14
# Batch [15/1000],Loss:120120008.0000
# Epoch [1000/1000],Loss:120120008.0000
# Current batch: 15
# Batch [16/1000],Loss:129646752.0000
# Epoch [1000/1000],Loss:129646752.0000
# Current batch: 16
# Batch [17/1000],Loss:134453712.0000
# Epoch [1000/1000],Loss:134453712.0000
# Current batch: 17
# Batch [18/1000],Loss:203349648.0000
# Epoch [1000/1000],Loss:203349648.0000
# Current batch: 18
# Batch [19/1000],Loss:118047272.0000
# Epoch [1000/1000],Loss:118047272.0000
# Current batch: 19
# Batch [20/1000],Loss:147716224.0000
# Epoch [1000/1000],Loss:147716224.0000
# Current batch: 20
# Batch [21/1000],Loss:143669680.0000
# Epoch [1000/1000],Loss:143669680.0000
# Current batch: 21
# Batch [22/1000],Loss:125074896.0000
# Epoch [1000/1000],Loss:125074896.0000
# Current batch: 22
# Batch [23/1000],Loss:177448464.0000
# Epoch [1000/1000],Loss:177448464.0000
# Current batch: 23
# Batch [24/1000],Loss:103536976.0000
# Epoch [1000/1000],Loss:103536976.0000
# Current batch: 24
# Batch [25/1000],Loss:181984880.0000
# Epoch [1000/1000],Loss:181984880.0000
# Current batch: 25
# Batch [26/1000],Loss:164921664.0000
# Epoch [1000/1000],Loss:164921664.0000
# Current batch: 26
# Batch [27/1000],Loss:168920848.0000
# Epoch [1000/1000],Loss:168920848.0000
# Current batch: 27
# Batch [28/1000],Loss:126138424.0000
# Epoch [1000/1000],Loss:126138424.0000
# Current batch: 28
# Batch [29/1000],Loss:150262400.0000
# Epoch [1000/1000],Loss:150262400.0000
# Current batch: 29
# Batch [30/1000],Loss:122777488.0000
# Epoch [1000/1000],Loss:122777488.0000
# Current batch: 30
# Batch [31/1000],Loss:95009720.0000
# Epoch [1000/1000],Loss:95009720.0000
# Current batch: 31
# Batch [32/1000],Loss:208758816.0000
# Epoch [1000/1000],Loss:208758816.0000
# Current batch: 32
# Batch [33/1000],Loss:119827224.0000
# Epoch [1000/1000],Loss:119827224.0000
# Current batch: 33
# Batch [34/1000],Loss:194275712.0000
# Epoch [1000/1000],Loss:194275712.0000
